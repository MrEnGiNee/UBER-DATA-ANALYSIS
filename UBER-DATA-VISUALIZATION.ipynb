# %% [markdown]
# # UBER DATA VISUALIZATION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load the dataset

uber = pd.read_csv('C:/Users/dell/Downloads/UBER/uber-raw-data.csv')

# %%
# Display the head of the dataset

uber.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564516 entries, 0 to 564515
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date/Time  564516 non-null  object
#  1   Lat        564516 non-null  float64
#  2   Lon        564516 non-null  float64
#  3   Base       564516 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 17.2+ MB

# %%
# Check if there is any missing values

def num_missing(x):
    return sum(x.isnull())
print('Number of missing/null values per column')
print(uber.apply(num_missing, axis=0))
# Out:
# Number of missing/null values per column
# Date/Time    0
# Lat          0
# Lon          0
# Base         0
# dtype: int64

# %%
uber.isnull().sum()
# Out:
# Date/Time    0
# Lat          0
# Lon          0
# Base         0
# dtype: int64

# %%
# Extract additional information
uber['Date/Time'] = pd.to_datetime(uber['Date/Time'], format="%m/%d/%Y %H:%M:%S")
uber['DayofWeekNum'] = uber['Date/Time'].dt.dayofweek
uber['DayofWeek'] = uber['Date/Time'].dt.day_name()
uber['DayNum'] = uber['Date/Time'].dt.day
uber['HourOfDay'] = uber['Date/Time'].dt.hour

# %%
# Display the head of the dataset
uber.head()
# Out:
#             Date/Time      Lat      Lon    Base  DayofWeekNum DayofWeek  \
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512             1   Tuesday
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512             1   Tuesday
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512             1   Tuesday
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512             1   Tuesday
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512             1   Tuesday
#
#    DayNum  HourOfDay
# 0       1          0
# 1       1          0
# 2       1          0
# 3       1          0
# 4       1          0

# %%
# Display the shape
uber.shape
# Out:
# (564516, 8)

# %%
# Unique base codes

uber['Base'].unique()
# Out:
# array(['B02512', 'B02598', 'B02617', 'B02682', 'B02764'], dtype=object)

# %%
# Total rides based on the base code

sns.catplot(x='Base', data=uber, kind='count')

# %%
uber_week_data = uber.pivot_table(index=['DayofWeekNum','DayofWeek'], values='Base', aggfunc='count')
uber_week_data
# Out:
#                           Base
# DayofWeekNum DayofWeek
# 0            Monday      60861
# 1            Tuesday     91185
# 2            Wednesday  108631
# 3            Thursday    85067
# 4            Friday      90303
# 5            Saturday    77218
# 6            Sunday      51251

# %%
# Visualize the pivot table
uber_week_data.plot(kind='bar', figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='DayofWeekNum,DayofWeek'>

# %%
uber_hourly_data = uber.pivot_table(index=['HourOfDay'], values='Base', aggfunc='count')
uber_hourly_data.plot(kind='line', figsize=(10,6), title='Hourly Journeys')
# Out:
# <AxesSubplot:title={'center':'Hourly Journeys'}, xlabel='HourOfDay'>

# %%
uber_day_data = uber.pivot_table(index=['DayNum'], values='Base', aggfunc='count')
uber_day_data.plot(kind='bar', figsize=(10,5), color='r', title='Journeys by DayNum')
# Out:
# <AxesSubplot:title={'center':'Journeys by DayNum'}, xlabel='DayNum'>

# %%
def count_rows(rows):
    return len(rows)

by_date = uber.groupby('DayNum').apply(count_rows)
by_date
# Out:
# DayNum
# 1     14546
# 2     17474
# 3     20701
# 4     26714
# 5     19521
# 6     13445
# 7     19550
# 8     16188
# 9     16843
# 10    20041
# 11    20420
# 12    18170
# 13    12112
# 14    12674
# 15    20641
# 16    17717
# 17    20973
# 18    18074
# 19    14602
# 20    11017
# 21    13162
# 22    16975
# 23    20346
# 24    23352
# 25    25095
# 26    24925
# 27    14677
# 28    15475
# 29    22835
# 30    36251
# dtype: int64

# %%
#Sort Day of the month by values rather than date
by_date_sorted = by_date.sort_values()
by_date_sorted
# Out:
# DayNum
# 20    11017
# 13    12112
# 14    12674
# 21    13162
# 6     13445
# 1     14546
# 19    14602
# 27    14677
# 28    15475
# 8     16188
# 9     16843
# 22    16975
# 2     17474
# 16    17717
# 18    18074
# 12    18170
# 5     19521
# 7     19550
# 10    20041
# 23    20346
# 11    20420
# 15    20641
# 3     20701
# 17    20973
# 29    22835
# 24    23352
# 26    24925
# 25    25095
# 4     26714
# 30    36251
# dtype: int64

# %%
# Analyze the hours

plt.hist(uber.HourOfDay, bins = 24, range = (.5, 24))
# Out:
# (array([ 7769.,  4935.,  5040.,  6095.,  9476., 18498., 24924., 22843.,
#         17939., 17865., 18774., 19425., 22603., 27190., 35324., 42003.,
#         45475., 43003., 38923., 36244., 36964., 30645., 20649.,     0.]),
#  array([ 0.5       ,  1.47916667,  2.45833333,  3.4375    ,  4.41666667,
#          5.39583333,  6.375     ,  7.35416667,  8.33333333,  9.3125    ,
#         10.29166667, 11.27083333, 12.25      , 13.22916667, 14.20833333,
#         15.1875    , 16.16666667, 17.14583333, 18.125     , 19.10416667,
#         20.08333333, 21.0625    , 22.04166667, 23.02083333, 24.        ]),
#  <BarContainer object of 24 artists>)

# %%
count_rows(uber)
by_hour_weekday = uber.groupby('HourOfDay DayofWeekNum'.split()).apply(count_rows).unstack()
by_hour_weekday
# Out:
# DayofWeekNum     0     1     2     3     4     5     6
# HourOfDay
# 0              518   765   899   792  1367  3027  4542
# 1              261   367   507   459   760  2479  2936
# 2              238   304   371   342   513  1577  1590
# 3              571   516   585   567   736  1013  1052
# 4             1021   887  1003   861   932   706   685
# 5             1619  1734  1990  1454  1382   704   593
# 6             2974  3766  4230  3179  2836   844   669
# 7             3888  5304  5647  4159  3943  1110   873
# 8             3138  4594  5242  3616  3648  1372  1233
# 9             2211  2962  3846  2654  2732  1764  1770
# 10            1953  2900  3844  2370  2599  2086  2113
# 11            1929  2949  3889  2516  2816  2315  2360
# 12            1945  2819  3988  2657  2978  2560  2478
# 13            2294  3556  4469  3301  3535  2685  2763
# 14            3117  4489  5438  4083  4087  3042  2934
# 15            3818  6042  7071  5182  5354  4457  3400
# 16            4962  7521  8213  6149  6259  5410  3489
# 17            5574  8297  9151  6951  6790  5558  3154
# 18            4725  7089  8334  6637  7258  6165  2795
# 19            4386  6459  7794  5929  6247  5529  2579
# 20            3573  6310  7783  6345  5165  4792  2276
# 21            3079  5993  6921  6585  6265  5811  2310
# 22            1976  3614  4845  5370  6708  6493  1639
# 23            1091  1948  2571  2909  5393  5719  1018

# %%
# heat map the brightest spot shows the day/hour with the highest frequency
plt.figure(figsize=(15,10))
sns.heatmap(by_hour_weekday)
# Out:
# <AxesSubplot:xlabel='DayofWeekNum', ylabel='HourOfDay'>

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt

plt.scatter(uber.iloc[:, 2], uber.iloc[:, 1])
plt.show()

# %% [markdown]
# ### UBER LOCATION TRACKER

# %%
import folium
import pandas as pd
uber_datanew = pd.DataFrame(uber)


# uber_data_values
uber_two_column = uber_datanew.loc[0:300, 'Lat':'Lon']

uber_data_values = uber_two_column.values.tolist()
newyork_map = folium.Map(location=[40.79659011772687, -73.87341741832425], zoom_start=13)
for point in range(0, len(uber_data_values)):
    folium.Marker(uber_data_values[point], popup=uber_data_values[point]).add_to(newyork_map)

newyork_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76983e9f598645a060e3548b0e56bcea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76983e9f598645a060e3548b0e56bcea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76983e9f598645a060e3548b0e56bcea = L.map(
#                 &quot;map_76983e9f598645a060e3548b0e56bcea&quot;,
#                 {
#                     center: [40.79659011772687, -73.87341741832425],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3e8bef6e2eb76f250b4cd4d9482be6e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_76983e9f598645a060e3548b0e56bcea);
#
#
#             var marker_739ce9978e3f93c42aa4f1c2ad6928bd = L.marker(
#                 [40.769, -73.9549],
#                 {}
#             ).addTo(map_76983e9f598645a060e3548b0e56bcea);
#
#
#         var popup_cba6d45ff9217861bd2e7a59a5969761 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d71d4072791ee5b8b4e2c66c98171ac = $(`&lt;div id=&quot;html_4d71d4072791ee5b8b4e2c66c98171ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.769, -73.9549]&lt;/div&gt;`)[0];
#                 popup_cba6d45ff9217861bd2e7a59a5969761.setContent(html_4d71d4072791ee5b8b4e2c66c98171ac);
#
#
#
#         marker_739ce9978e3f93c42aa4f1c2ad6928bd.bindPopup(popup_cba6d45ff9217861bd2e7a59a5969761)
#         ;
#
#
#
#
#             var marker_657c5661fa4d9abf8c7dff4759f97cab = L.marker(
#                 [40.7267, -74.0345],
#                 {}
#             ).addTo(map_76983e9f598645a060e3548b0e56bcea);
#
#
#         var popup_69d5bbf62c749966f04853d4ff9ab606 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3bf689ac908dbfa0fd830331654fdecb = $(`&lt;div id=&quot;html_3bf689ac908dbfa0fd830331654fdecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.7267, -74.0345]&lt;/div&gt;`)[0];
#                 popup_69d5bbf62c749966f04853d4ff9ab606.setContent(html_3bf689ac908dbfa0fd830331654fdecb);
#
#
#
#         marker_657c5661fa4d9abf8c7dff4759f97cab.bindPopup(popup_69d5bbf62c749966f04853d4ff9ab606)
#         ;
#
#
#
#
#             var marker_e4b78c140e8a3d3828034d591d1a0f7d = L.marker(
#                 [40.7316, -73.9873],
#                 {}
#             ).addTo(map_76983e9f598645a060e3548b0e56bcea);
#
#
#         var popup_a3ac00f12461ff45b6dcae0790437f9a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_655a54d061f367d0a9e8b70cf5f48289 = $(`&lt;div id=&quot;html_655a54d061f367d0a9e8b70cf5f48289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.7316, -73.9873]&lt;/div&gt;`)[0];
#                 popup_a3ac00f12461ff45b6dcae0790437f9a.setContent(html_655a54d061f367d0a9e8b70cf5f48289);
#
#
#
#         marker_e4b78c140e8a3d3828034d591d1a0f7d.bindPopup(popup_a3ac00f12461ff45b6dcae0790437f9a)
#         ;
#
#
#
#
#             var marker_6a44d85dd8a3de77fe5ad916cc718706 = L.marker(
#                 [40.7588, -73.9776],
#                 {}
#             ).addTo(map_76983e9f598645a060e3548b0e56bcea);
#
#
#         var popup_885c201b3c969d341e72e33bace274a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bb4339e6d17875ca57a67c17dc5d5ed = $(`&lt;div id=&quot;html_8bb4339e6d17875ca57a67c17dc5d5ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.7588, -73.9776]&lt;/div&gt;`)[0];
#                 popup_885c201b3c969d341e72e33bace274a3.setContent(html_8bb4339e6d17875ca57a67c17dc5d5ed);
#
#
#
#         marker_6a44d85dd8a3de77fe5ad916cc718706.bindPopup(popup_885c201b3c969d341e72e33bace274a3)
#         ;
#
#
#
#
#             var marker_96997e549ff1414d2f28a257fedb2bbe = L.marker(
#                 [40.7594, -73.9722],
#                 {}
#             ).addTo(map_76983e9f598645a060e3548b0e56bcea);
#
#
#         var popup_d8472f234c7b651d4b4ed55d80e299c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d25d9fa2f40fc90ce8f0c711dc27abc = $(`&lt;div id=&quot;html_3d25d9fa2f40fc90ce8f0c711dc27abc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[40.7594, -73.9722]&lt;/div&gt;`)[0];
#                 popup_d8472f234c7b651d4b4ed55d80e299c9.setContent(html_3d25d9fa2f40fc90ce8f0c711dc27abc);
#
#
#
#         marker_96997e549ff1414d2f28a257fedb2bbe.bindPopup(popup_d8472f234c7b651d4b4ed55d80e299c9)
#         ;
#
#
#
#
#             var marker_ec6f450dbc964fb1e6e93b109611afef = L.marker(
#                 [40.7383,
